# %% [markdown]
# ## Initial machine learning training
# Goal: Develop a baseline machine learning model that emulates `t_ref` SPEAR data over time
#
# - The `PP_data.py` script was used to procress the data in DATA/: (read -> interpolate -> split -> normalize -> write to PP_DATA)
# - The data contains 3 main variables `training`, `validating`, and `testing`
# - The `mean` and `std` variables can be used to denormalize the data (note that the mean and std are based off the training data only)
# - Implemented a CNN model:
#     - Input channels: ['t_ref(t-3)', 't_ref(t-2)', 't_ref(t-1)', 'lat_sin', 'lat_cos', 'lon_sin', 'lon_cos']
#     - Targets: [t_ref(t)]
#     - nepochs = 50
#     - learning_rate = 0.001
#     - Batch_size = 32
# - Expanded baseline model by adding batch normalization
# - Expanded model by implementing a encoder/decoder

# %%
from utils.utils import VarSet, DataSet
from architectures.cnn_baseline import CNN2D, set_seed, Results

num_epochs = 50
set_seed()

t_ref = VarSet(
    var_name="t_ref",
    file_name="PP_DATA/t_ref.192101-201012.nc",
    is_output=True
)

spatial_features = VarSet(
    var_name="spatial_features",
    file_name="PP_DATA/spatial_features.nc",
    is_static=True
)

variables = [t_ref] #, spatial_features]
data = DataSet(set_name="set1", variables=variables)
lon, lat = t_ref.get_grid()
time_test = t_ref.get_time('time_test')

# %%
set_seed()
Baseline = CNN2D(data, case=0, label="baseline_no_spatial")
Baseline.train()
Baseline.plot_loss_over_epochs()

set_seed()
Model2 = CNN2D(data, case=1, label="baseline_batchnorm_no_spatial")
Model2.train()
Model2.plot_loss_over_epochs()

set_seed()
Model3 = CNN2D(data, case=2, label="baseline_batchnorm_sampling_no_spatial")
Model3.train()
Model3.plot_loss_over_epochs()
# Out:
# baseline_no_spatial - Sequential(
#   (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# baseline_no_spatial - Input channels: 3
# baseline_no_spatial - Output channels: 1
# baseline_no_spatial - Number of epochs: 50
# baseline_no_spatial - Batch Size: 32
# baseline_no_spatial - Learning Rate: 0.001
# baseline_no_spatial - Inputs: ['t_ref(t-3)', 't_ref(t-2)', 't_ref(t-1)']
# baseline_no_spatial - Targets: ['t_ref']
# baseline_no_spatial - Epoch 10/50, Train Loss (t_ref): 0.0303, Validation Loss (t_ref): 0.0292
# baseline_no_spatial - Epoch 20/50, Train Loss (t_ref): 0.0260, Validation Loss (t_ref): 0.0237
# baseline_no_spatial - Epoch 30/50, Train Loss (t_ref): 0.0241, Validation Loss (t_ref): 0.0292
# ...

# %%
Model_results = Results()
Model_results.add_model_output(Baseline)
Model_results.add_model_output(Model2)
Model_results.add_model_output(Model3)

Model_results.plot_global_RMSE('t_ref')
Model_results.plot_temporal_RMSE('t_ref', time_test)
Model_results.plot_spatial_RMSE("t_ref", lon, lat)
# Out:
# Persistence-output - Calculating RMSE for target: t_ref
# Persistence-output - Global RMSE: t_ref :: 4.339350700378418
# baseline_no_spatial-output - Calculating RMSE for target: t_ref
# baseline_no_spatial-output - Global RMSE: t_ref :: 3.279585361480713
# baseline_batchnorm_no_spatial-output - Calculating RMSE for target: t_ref
# baseline_batchnorm_no_spatial-output - Global RMSE: t_ref :: 3.1469078063964844
# baseline_batchnorm_sampling_no_spatial-output - Calculating RMSE for target: t_ref
# baseline_batchnorm_sampling_no_spatial-output - Global RMSE: t_ref :: 2.405672311782837
# /net/unr/SPEAR_EMULATOR/architectures/cnn_baseline.py:440: FutureWarning: In a future version of xarray to_datetimeindex will default to returning a 'us'-resolution DatetimeIndex instead of a 'ns'-resolution DatetimeIndex. This warning can be silenced by explicitly passing the `time_unit` keyword argument.
#   time_converted = time_test.to_index().to_datetimeindex()
# ...

# %%
Model_results = Results()
Model_results.add_model_output(Baseline, run_type="forecast_rollout")
Model_results.add_model_output(Model2, run_type="forecast_rollout")
Model_results.add_model_output(Model3, run_type="forecast_rollout")

Model_results.plot_global_RMSE('t_ref')
Model_results.plot_temporal_RMSE('t_ref', time_test)
Model_results.plot_spatial_RMSE("t_ref", lon, lat)
# Out:
# baseline_no_spatial - Doing inference for 117 time steps
# baseline_no_spatial-output - Calculating RMSE for target: t_ref
# baseline_no_spatial-output - Global RMSE: t_ref :: 34.83505630493164
# baseline_batchnorm_no_spatial - Doing inference for 117 time steps
# baseline_batchnorm_no_spatial-output - Calculating RMSE for target: t_ref
# baseline_batchnorm_no_spatial-output - Global RMSE: t_ref :: 898.6190185546875
# baseline_batchnorm_sampling_no_spatial - Doing inference for 117 time steps
# baseline_batchnorm_sampling_no_spatial-output - Calculating RMSE for target: t_ref
# baseline_batchnorm_sampling_no_spatial-output - Global RMSE: t_ref :: 27.62725830078125
# /net/unr/SPEAR_EMULATOR/architectures/cnn_baseline.py:440: FutureWarning: In a future version of xarray to_datetimeindex will default to returning a 'us'-resolution DatetimeIndex instead of a 'ns'-resolution DatetimeIndex. This warning can be silenced by explicitly passing the `time_unit` keyword argument.
# ...
